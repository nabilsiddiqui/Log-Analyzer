# %% [markdown]
# # Reading the log file

# %%
import pandas as pd
df = pd.read_csv("userlog.log", sep = "\t\t", header = None)
df.columns = ["Date & time", "activity","server","user"]
# Out:
# C:\Users\oeluc\Anaconda3\envs\tfdeeplearning\lib\site-packages\ipykernel_launcher.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.

# %%
df
# Out:
#                     Date & time    activity                     server  \
# 0     2020-05-23 00:44:42        login       mailserver.local
# 1     2020-05-15 10:54:11        logout      mailserver.local
# 2     2020-05-07 11:25:24        login       myworkstation.local
# 3     2020-05-14 16:31:34        logout      webserver.local
# 4     2020-05-12 17:02:10        login       mailserver.local
# ...                         ...         ...                        ...
# 4995  2020-05-27 20:49:37        logout      mailserver.local
# 4996  2020-05-19 03:18:58        logout      myworkstation.local
# 4997  2020-05-30 10:28:28        login       myworkstation.local
# 4998  2020-05-25 22:59:12        login       mailserver.local
# 4999  2020-05-05 09:42:02        logout      myworkstation.local
#
#                                       user
# 0            melaina.gabeline@yahoo.com.mx
# 1          sevan.stephco@miho-nakayama.com
# 2                   breena.benassi@gmx.net
# 3             arti.karshner@mail2perry.com
# 4                  queen.ham@quiklinks.com
# ...                                    ...
# 4995             isiah.walson@yahoo.com.mx
# 4996      queen.sirucek@mail2emergency.com
# 4997         remington.caffrey@estranet.it
# 4998           loriann.ryba@mail2perry.com
# 4999  kirsten.pflughoeft@mail2srilanka.com
#
# [5000 rows x 4 columns]

# %% [markdown]
# ## Preprocessing
#
# We would need to do some pre processing suchas as separating date and time columns. Convert the string that are in date and time to actual date format. Trimming strings in the activity column from the right and finally sorting the data accroding to date time and user

# %%
import datetime
df['time'] = df["Date & time"].apply(lambda x: x.split(' ')[1])
df['date'] = df["Date & time"].apply(lambda x: x.split(' ')[0])
df = df.drop(columns = ["Date & time"])

df['date'] = pd.to_datetime(df['date'],
                                format="%Y/%m/%d",
                                errors='raise')

df['time'] = pd.to_datetime(df['time'],
                                format= "%H:%M:%S",
                                errors='raise')

df['time'] = df['time'].dt.time

df.activity = df.activity.apply(lambda x: x.strip())

df = df[['date','time','user','server','activity']]
df.sort_values(['date','time','user'],inplace = True)
df
# Out:
#            date      time                                  user  \
# 3229 2020-05-01  00:04:23                 lupe.gave@freesurf.fr
# 2604 2020-05-01  00:08:47  kirsten.pflughoeft@mail2srilanka.com
# 4742 2020-05-01  01:30:53                breena.benassi@gmx.net
# 1960 2020-05-01  01:45:55        maryelizabeth.ryba@freesurf.fr
# 1378 2020-05-01  01:51:58          arti.karshner@mail2perry.com
# ...         ...       ...                                   ...
# 5    2020-05-30  23:01:30     maryelizabeth.stassen@freesurf.fr
# 134  2020-05-30  23:05:55       rayon.crumly@mail2champaign.com
# 3668 2020-05-30  23:37:45         tarrin.evanoff@blacksburg.net
# 2097 2020-05-30  23:39:23             isiah.walson@yahoo.com.mx
# 2194 2020-05-30  23:50:24      torrell.mckown@miho-nakayama.com
#
#                          server activity
# 3229  mailserver.local             login
# 2604  mailserver.local            logout
# 4742  webserver.local              login
# 1960  webserver.local             logout
# 1378  webserver.local              login
# ...                         ...      ...
# 5     mailserver.local            logout
# 134   myworkstation.local         logout
# 3668  mailserver.local            logout
# 2097  webserver.local              login
# 2194  mailserver.local            logout
#
# [5000 rows x 5 columns]
